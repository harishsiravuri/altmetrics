# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
import pandas as pd

# %%
raw_data=pd.read_csv("C:\\Users\\haris\\Desktop\\sampled2.csv")
npMatrix = np.matrix(raw_data)

# %%
X, y = npMatrix[1:,1], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Mendeley Readers')
plt.ylabel('Altmetric Score')
plt.title('Relation between the number of mendeley readers and the altmetric score')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,2], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Citeulike Readers')
plt.ylabel('Altmetric Score')
plt.title('Relation between the number of mendeley readers and the altmetric score')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,3], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Connotea Readers')
plt.ylabel('Altmetric Score')
plt.title('Relation between the number of mendeley readers and the altmetric score')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,4], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Blog users')
plt.ylabel('Altmetric Score')
plt.title('Relation between the number of mendeley readers and the altmetric score')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,5], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Blog posts')
plt.ylabel('Altmetric Score')
plt.title('Relation between the number of mendeley readers and the altmetric score')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,6], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('News')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,7], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Total Posts')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,8], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Wikipedia posts')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,9], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Facebook users')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,10], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Facebook posts')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,11], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Twitter users')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,12], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Twitter posts')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,13], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Citation Page')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,14], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Other articles')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,15], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Mean')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,16], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Rank')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,17], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Perc')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,18], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Scored higher than')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,19], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Sample size')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,20], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_lecturers')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,21], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_librarian')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,22], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_bachelors')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,22], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_bachelors')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,23], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_masters')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,24], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_pg')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,25], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_phd')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,26], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_student_doct')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,27], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_researchers')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,28], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_others')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,29], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_prof_assoc')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,30], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_prof')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,31], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_medi')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,32], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_ss')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,33], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_psych')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,34], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_earth')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,35], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_agri')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,36], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_arts')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,37], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_us')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,38], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_th')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,39], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_ie')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,40], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_id')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,41], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_au')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()

# %%
X, y = npMatrix[1:,42], npMatrix[1:,43]
plt.scatter(X,y, label=' ', color='k', s=25, marker="o")
plt.xlabel('Users_gb')
plt.ylabel('Altmetric Score')
plt.title('')
plt.legend()
plt.show()
